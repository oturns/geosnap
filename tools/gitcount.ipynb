# %% [markdown]
# ## geosnap Change Log Statistics
#
# This notebook generates the summary statistics for a package.
#
# It assumes you are running this under the `tools` directory at the toplevel of the package

# %% [markdown]
# ## Change the values only in the next cell

# %%
package_name = 'geosnap'
release_date = '2020-03-11'
start_date = '2019-01-30'

# %% [markdown]
# This notebook will generate a file in the current directory with the name "changelog_VERSION.md". You can edit and append this on front of the CHANGELOG file for the package release.

# %%
from __future__ import print_function
import os
import json
import re
import sys
import pandas

from datetime import datetime, timedelta
from time import sleep
from subprocess import check_output
try:
    from urllib import urlopen
except:
    from urllib.request import urlopen

import ssl
import yaml

context = ssl._create_unverified_context()

# %%
CWD = os.path.abspath(os.path.curdir)

# %%
CWD
# Out:
# '/Users/knaaptime/projects/geosnap/tools'

# %%
since_date = '--since="{start}"'.format(start=start_date)
since_date
since = datetime.strptime(start_date+" 0:0:0", "%Y-%m-%d %H:%M:%S")
since
# Out:
# datetime.datetime(2019, 1, 30, 0, 0)

# %%
# get __version__
f = "../{package}/__init__.py".format(package=package_name)

with open(f, 'r') as initfile:
     exec(initfile.readline())

# %% [markdown]
# ## Total commits by subpackage

# %%
cmd = ['git', 'log', '--oneline', since_date]
ncommits = len(check_output(cmd).splitlines())

# %%
ncommits
# Out:
# 438

# %% [markdown]
# ## List Contributors

# %% [markdown]
# Some of our contributors have many aliases for the same identity. So, we've added a mapping to make sure that individuals are listed once (and only once).

# %%
identities = {'Levi John Wolf': ('ljwolf', 'Levi John Wolf'),
              'Serge Rey': ('Serge Rey', 'Sergio Rey', 'sjsrey', 'serge'),
              'Wei Kang': ('Wei Kang', 'weikang9009'),
              'Dani Arribas-Bel': ('Dani Arribas-Bel', 'darribas')
}

def regularize_identity(string):
    string = string.decode()
    for name, aliases in identities.items():
        for alias in aliases:
            if alias in string:
                string = string.replace(alias, name)
    if len(string.split(' '))>1:
        string = string.title()
    return string.lstrip('* ')

# %%
author_cmd = ['git', 'log', '--format=* %aN', since_date]

# %%
from collections import Counter

# %%
ncommits = len(check_output(cmd).splitlines())
all_authors = check_output(author_cmd).splitlines()
counter = Counter([regularize_identity(author) for author in all_authors])
#        global_counter += counter
#        counters.update({'.'.join((package,subpackage)): counter})
unique_authors = sorted(set(all_authors))

# %%
unique_authors = counter.keys()

# %%
unique_authors
# Out:
# dict_keys(['Eli Knaap', 'Wei Kang', 'Serge Rey', 'Su Han', 'Renan Xavier Cortes', 'Renanxcortes'])

# %% [markdown]
# ## Disaggregate by PR, Issue

# %%
from datetime import datetime, timedelta
ISO8601 = "%Y-%m-%dT%H:%M:%SZ"
PER_PAGE = 100
element_pat = re.compile(r'<(.+?)>')
rel_pat = re.compile(r'rel=[\'"](\w+)[\'"]')

# %%
def parse_link_header(headers):
    link_s = headers.get('link', '')
    urls = element_pat.findall(link_s)
    rels = rel_pat.findall(link_s)
    d = {}
    for rel,url in zip(rels, urls):
        d[rel] = url
    return d

def get_paged_request(url):
    """get a full list, handling APIv3's paging"""
    results = []
    while url:
        #print("fetching %s" % url, file=sys.stderr)
        f = urlopen(url)
        results.extend(json.load(f))
        links = parse_link_header(f.headers)
        url = links.get('next')
    return results

def get_issues(project="pysal/pysal", state="closed", pulls=False):
    """Get a list of the issues from the Github API."""
    which = 'pulls' if pulls else 'issues'
    url = "https://api.github.com/repos/%s/%s?state=%s&per_page=%i" % (project, which, state, PER_PAGE)
    return get_paged_request(url)


def _parse_datetime(s):
    """Parse dates in the format returned by the Github API."""
    if s:
        return datetime.strptime(s, ISO8601)
    else:
        return datetime.fromtimestamp(0)


def issues2dict(issues):
    """Convert a list of issues to a dict, keyed by issue number."""
    idict = {}
    for i in issues:
        idict[i['number']] = i
    return idict


def is_pull_request(issue):
    """Return True if the given issue is a pull request."""
    return 'pull_request_url' in issue


def issues_closed_since(period=timedelta(days=365), project="pysal/pysal", pulls=False):
    """Get all issues closed since a particular point in time. period
can either be a datetime object, or a timedelta object. In the
latter case, it is used as a time before the present."""

    which = 'pulls' if pulls else 'issues'

    if isinstance(period, timedelta):
        period = datetime.now() - period
    url = "https://api.github.com/repos/%s/%s?state=closed&sort=updated&since=%s&per_page=%i" % (project, which, period.strftime(ISO8601), PER_PAGE)
    allclosed = get_paged_request(url)
    # allclosed = get_issues(project=project, state='closed', pulls=pulls, since=period)
    filtered = [i for i in allclosed if _parse_datetime(i['closed_at']) > period]

    # exclude rejected PRs
    if pulls:
        filtered = [ pr for pr in filtered if pr['merged_at'] ]

    return filtered


def sorted_by_field(issues, field='closed_at', reverse=False):
    """Return a list of issues sorted by closing date date."""
    return sorted(issues, key = lambda i:i[field], reverse=reverse)


def report(issues, show_urls=False):
    """Summary report about a list of issues, printing number and title.
    """
    # titles may have unicode in them, so we must encode everything below
    if show_urls:
        for i in issues:
            role = 'ghpull' if 'merged_at' in i else 'ghissue'
            print('* :%s:`%d`: %s' % (role, i['number'],
                                        i['title'].encode('utf-8')))
    else:
        for i in issues:
            print('* %d: %s' % (i['number'], i['title'].encode('utf-8')))

# %%
all_issues = {}
all_pulls = {}
total_commits = 0
#prj='pysal/libpysal'
prj = 'spatialucr/{package}'.format(package=package_name)
issues = issues_closed_since(since, project=prj,pulls=False)
pulls = issues_closed_since(since, project=prj,pulls=True)
issues = sorted_by_field(issues, reverse=True)
pulls = sorted_by_field(pulls, reverse=True)
n_issues, n_pulls = map(len, (issues, pulls))
n_total = n_issues + n_pulls

# %%
issue_listing = []
for issue in issues:
    entry = "{title} (#{number})".format(title=issue['title'],number=issue['number'])
    issue_listing.append(entry)

# %%
pull_listing = []
for pull in pulls:
    entry = "{title} (#{number})".format(title=pull['title'],number=pull['number'])
    pull_listing.append(entry)

# %%
pull_listing
# Out:
# ['Datasets (#205)',
#  'bump pyarrow (#204)',
#  'bump version (#200)',
#  'Merge pull request #199 from knaaptime/master (#199)',
#  'Merge pull request #197 from knaaptime/master (#197)',
#  'Merge pull request #196 from knaaptime/master (#196)',
#  'Merge pull request #195 from knaaptime/master (#195)',
#  'Merge pull request #194 from knaaptime/master (#194)',
#  'remove unnecessary options from setup.py (#193)',
#  'update docs; (#192)',
#  'Merge pull request #191 from knaaptime/prep (#191)',
#  'Merge pull request #190 from knaaptime/prep (#190)',
#  'Vizsu (#187)',
#  'Update (#185)',
#  'fix for lodes constructor (#183)',
#  'Update README.md (#182)',
#  'bug: drop duplicates from lehd (#181)',
#  'add pooling option to clustering (#180)',
#  'intersphinx and docstrings (#179)',
#  'update (#178)',
#  'update harmonize for new tobler api (#175)',
#  'update (#177)',
#  'Vizsu (#174)',
#  'point to reloacated  metadata in setup.py (#171)',
#  'release prep (#165)',
#  'fix years test in lodes constructor (#164)',
#  'add user guide to apidoc navbar (#163)',
#  'cosmetic updates to api docs (#162)',
#  'fix lodes constructor and allow kwargs passed to weights  (#161)',
#  'two fixes (#160)',
#  'refactor (#158)',
#  'Update (#156)',
#  'update docs (#155)',
#  'nojekyll (#153)',
#  'move docs to gh-pages (#152)',
#  'Cleaning files (#151)',
#  'Update GEOSNAP2ACM and GEOSNAP2NAM (#150)',
#  'Boundaryfix (#149)',
#  'Update GEOSNAP2NAM.py (#147)',
#  'update Readme and move LTDB_data_availability.xlsx (#143)',
#  'fixed error in labelling (#142)',
#  'GEOSNAP2NAM new version (#141)',
#  'ENH: Makefile for joint tobler and geosnap dev environments (#139)',
#  'Harmonize (#137)',
#  'ENH: Dockerfile for join dev of geosnap and tobler. (#135)',
#  'update outputs for GEOSNAP2ACM and GEOSNAP2NAM (#136)',
#  'Jupyter Notebook for Adaptive Choropleth Mapper and Neighborhood Analysis Mapper (#134)',
#  'BUG: extensive_variables and intensive_variables default to None not … (#133)',
#  'ENH: adding template example (#131)',
#  'remove errant files (#130)',
#  'starting branch to explore prototypes (#129)',
#  'update environment.yml (#128)',
#  'update .coveragerc to ignore viz and util (#127)',
#  'add harmonization tests (#126)',
#  'refactor dynamics module (#125)',
#  'improvements to harmonize function (#124)',
#  'better handling of cluster internals (#123)',
#  'allow returning cluster instances and return new community with methods (#121)',
#  'BUG: extensive != intensive (#122)',
#  'update requirements (#120)',
#  'CLI/Docker (#119)',
#  '[ENH] better tract handling (#118)',
#  'check for block data inside data store (#117)',
#  'add lodes constructor (#114)',
#  'define harmonize in geosnap (#115)',
#  'Docker (#112)',
#  'start harmonization module (#111)',
#  'update readme (#110)',
#  'update notebooks (#108)',
#  'fix imports in cenpy fetch (#106)',
#  'remove notebook checkpoint dir (#105)',
#  'remove old parquet file from setup script (#104)',
#  'add dash dataset explorer (#102)',
#  'update cenpy fetcher (#103)',
#  '(ENH) add function for visualizing compositions of neighborhood sequence clusters  (#96)',
#  'Docker (#100)',
#  'rewrite Community class and internal data handling (#97)',
#  'start lehd branch (#92)',
#  'test plotting and catch quilt error (#79)',
#  'Geosnap refactor (#75)',
#  'Dependencies (#72)',
#  'update travis yaml to use newer miniconda (#71)',
#  'this PR moves all data mangement into quilt and fixes tests accordingly (#65)',
#  'beginning a `util` module (#63)',
#  'Update Sequence class (#56)',
#  'Allow all the currency variables to be adjusted for inflation. (#62)',
#  'add an option to specify constant year for inflation adjustment (#55)',
#  'remove rounding in ltdb data reader (#57)',
#  'update readme and some infrastucture changes (#52)']

# %%
message = "We closed a total of {total} issues (enhancements and bug fixes) through {pr} pull requests".format(total=n_total, pr=n_pulls)

# %%
message = "{msg}, since our last release on {previous}.".format(msg=message, previous=str(start_date))

# %%
message
# Out:
# 'We closed a total of 237 issues (enhancements and bug fixes) through 89 pull requests, since our last release on 2019-01-30.'

# %%
message += "\n\n## Issues Closed\n"

# %%
print(message)
# Out:
# We closed a total of 237 issues (enhancements and bug fixes) through 89 pull requests, since our last release on 2019-01-30.
#
# ## Issues Closed

# %%
issues = "\n".join(["  - "+issue for issue in issue_listing])
message += issues
message += "\n\n## Pull Requests\n"
pulls = "\n".join(["  - "+pull for pull in pull_listing])
message += pulls

# %%
print(message)
# Out:
# We closed a total of 237 issues (enhancements and bug fixes) through 89 pull requests, since our last release on 2019-01-30.
#
# ## Issues Closed
#   - import broken with newer quilt versions (#201)
#   - Datasets (#205)
#   - User authentication (#41)
#   - migrate quilt data (#167)
#   - release prep (#170)
#   - issues with core data (#166)
#   - Google Colab pip install issue (#206)
#   - bump pyarrow (#204)
#   - bumpy pyarrow version (#203)
#   - bump version (#200)
#   - Merge pull request #199 from knaaptime/master (#199)
#   - Merge pull request #197 from knaaptime/master (#197)
#   - Merge pull request #196 from knaaptime/master (#196)
#   - Merge pull request #195 from knaaptime/master (#195)
#   - Merge pull request #194 from knaaptime/master (#194)
#   - remove unnecessary options from setup.py (#193)
#   - update docs; (#192)
#   - Merge pull request #191 from knaaptime/prep (#191)
#   - Merge pull request #190 from knaaptime/prep (#190)
#   - Vizsu (#187)
#   - Release on Conda? (#186)
#   - Update (#185)
#   - fix for lodes constructor (#183)
#   - Update README.md (#182)
#   - bug: drop duplicates from lehd (#181)
#   - add pooling option to cluster analytics (#84)
#   - add pooling option to clustering (#180)
#   - remove property decorators from datasets (#169)
#   - intersphinx and docstrings (#179)
#   - update (#178)
#   - update harmonize for new tobler api (#175)
#   - update (#177)
#   - upload images (#176)
#   - Vizsu (#174)
#   - big fix (#173)
#   - Vizsu (#172)
#   - point to reloacated  metadata in setup.py (#171)
#   - release prep (#165)
#   - fix years test in lodes constructor (#164)
#   - add user guide to apidoc navbar (#163)
#   - cosmetic updates to api docs (#162)
#   - fix lodes constructor and allow kwargs passed to weights  (#161)
#   - two fixes (#160)
#   - how to store the results of Community.cluster (#145)
#   - consider storing cluster metadata on a `Community` (#144)
#   - include tests for example notebooks (#159)
#   - nlcd is required for example 3 (#138)
#   - refactor (#158)
#   - generate DOI (#81)
#   - Update (#156)
#   - consider move to mkdocs (#140)
#   - update docs (#155)
#   - nojekyll (#153)
#   - move docs to gh-pages (#152)
#   - Cleaning files (#151)
#   - Update GEOSNAP2ACM and GEOSNAP2NAM (#150)
#   - Boundaryfix (#149)
#   - Update GEOSNAP2NAM.py (#147)
#   - updated comments in GEOSNAP2NAM.py (#146)
#   - update Readme and move LTDB_data_availability.xlsx (#143)
#   - fixed error in labelling (#142)
#   - GEOSNAP2NAM new version (#141)
#   - ENH: Makefile for joint tobler and geosnap dev environments (#139)
#   - Harmonize (#137)
#   - ENH: Dockerfile for join dev of geosnap and tobler. (#135)
#   - update outputs for GEOSNAP2ACM and GEOSNAP2NAM (#136)
#   - Jupyter Notebook for Adaptive Choropleth Mapper and Neighborhood Analysis Mapper (#134)
#   - BUG: extensive_variables and intensive_variables default to None not … (#133)
#   - Do we have example datasets with column defining neighborhood clusters for demonstration/testing purpose?  (#95)
#   - adding a table after the chropleth map in examples/02_creating_community_datasets.ipynb (#45)
#   - ENH: adding template example (#131)
#   - remove errant files (#130)
#   - consider pysal submodule (#93)
#   - starting branch to explore prototypes (#129)
#   - place api (#74)
#   - add tests (#66)
#   - update environment.yml (#128)
#   - add quilt3 in dependencies (#113)
#   - update .coveragerc to ignore viz and util (#127)
#   - add harmonization tests (#126)
#   - refactor dynamics module (#125)
#   - improvements to harmonize function (#124)
#   - geosnap depends on not most update scikit-learn api (#94)
#   - better handling of cluster internals (#123)
#   - return cluster instance  (#82)
#   - allow returning cluster instances and return new community with methods (#121)
#   - BUG: extensive != intensive (#122)
#   - add harmonization interface (#109)
#   - rework CI (#98)
#   - update requirements (#120)
#   - CLI/Docker (#119)
#   - [ENH] better tract handling (#118)
#   - (bug) inconsistency of localizing quilt3 data sets (#116)
#   - check for block data inside data store (#117)
#   - add lodes constructor (#114)
#   - define harmonize in geosnap (#115)
#   - Docker (#112)
#   - start harmonization module (#111)
#   - typo (#86)
#   - Creating a database fails due to bad file name (#23)
#   - update readme (#110)
#   - notebooks are not running successfully (#107)
#   - update notebooks (#108)
#   - Fix mislabeling in geosnap.data.dictionary (#90)
#   - parallelize gdf from wkb (#91)
#   - fix imports in cenpy fetch (#106)
#   - remove notebook checkpoint dir (#105)
#   - remove old parquet file from setup script (#104)
#   - add dash dataset explorer (#102)
#   - update census fetcher to use new cenpy api (#87)
#   - update cenpy fetcher (#103)
#   - dash chorobrewer explorer (#99)
#   - (ENH) add function for visualizing compositions of neighborhood sequence clusters  (#96)
#   - error related quilt upgrade to 3.0 (#85)
#   - Docker (#100)
#   - rewrite Community class and internal data handling (#97)
#   - cenpy interface (#73)
#   - consider GADM interface (#42)
#   - add a private function that loads all geoms into memory (#49)
#   - [WIP] Start of harmonization layer (#80)
#   - refactor Dataset to Community (#36)
#   - start lehd branch (#92)
#   - GEOSNAP2ACM (#89)
#   - Add GEOSNAP2ACM (#88)
#   - investigate moving from CGI to django (#50)
#   - parameter description of Kmeans (#51)
#   - catch error and update quilt package (#69)
#   - test plotting and catch quilt error (#79)
#   - importing geosnap (KeyError: 'states'?) (#78)
#   - Geosnap refactor (#75)
#   - bug: installation error on networkx  (#64)
#   - trim dependencies (#70)
#   - Dependencies (#72)
#   - update travis yaml to use newer miniconda (#71)
#   - move quilt data to spatialucr account (#28)
#   - move all shape data to quilt (#48)
#   - fix cluster tests (#58)
#   - expose util functions to users (#60)
#   - this PR moves all data mangement into quilt and fixes tests accordingly (#65)
#   - beginning a `util` module (#63)
#   - Update Sequence class (#56)
#   - LTDB reader: adjust for inflation? (#53)
#   - Allow all the currency variables to be adjusted for inflation. (#62)
#   - Reading LTBD data - inconsistent paths for full count and sample files? (#61)
#   - LTDB reader rounding to integers? (#54)
#   - add an option to specify constant year for inflation adjustment (#55)
#   - remove rounding in ltdb data reader (#57)
#   - update readme and some infrastucture changes (#52)
#
# ## Pull Requests
#   - Datasets (#205)
#   - bump pyarrow (#204)
#   - bump version (#200)
#   - Merge pull request #199 from knaaptime/master (#199)
#   - Merge pull request #197 from knaaptime/master (#197)
#   - Merge pull request #196 from knaaptime/master (#196)
#   - Merge pull request #195 from knaaptime/master (#195)
#   - Merge pull request #194 from knaaptime/master (#194)
#   - remove unnecessary options from setup.py (#193)
#   - update docs; (#192)
#   - Merge pull request #191 from knaaptime/prep (#191)
#   - Merge pull request #190 from knaaptime/prep (#190)
#   - Vizsu (#187)
#   - Update (#185)
#   - fix for lodes constructor (#183)
#   - Update README.md (#182)
#   - bug: drop duplicates from lehd (#181)
#   - add pooling option to clustering (#180)
#   - intersphinx and docstrings (#179)
#   - update (#178)
#   - update harmonize for new tobler api (#175)
#   - update (#177)
#   - Vizsu (#174)
#   - point to reloacated  metadata in setup.py (#171)
#   - release prep (#165)
#   - fix years test in lodes constructor (#164)
#   - add user guide to apidoc navbar (#163)
#   - cosmetic updates to api docs (#162)
#   - fix lodes constructor and allow kwargs passed to weights  (#161)
#   - two fixes (#160)
#   - refactor (#158)
#   - Update (#156)
#   - update docs (#155)
#   - nojekyll (#153)
#   - move docs to gh-pages (#152)
#   - Cleaning files (#151)
#   - Update GEOSNAP2ACM and GEOSNAP2NAM (#150)
#   - Boundaryfix (#149)
#   - Update GEOSNAP2NAM.py (#147)
#   - update Readme and move LTDB_data_availability.xlsx (#143)
#   - fixed error in labelling (#142)
#   - GEOSNAP2NAM new version (#141)
#   - ENH: Makefile for joint tobler and geosnap dev environments (#139)
#   - Harmonize (#137)
#   - ENH: Dockerfile for join dev of geosnap and tobler. (#135)
#   - update outputs for GEOSNAP2ACM and GEOSNAP2NAM (#136)
#   - Jupyter Notebook for Adaptive Choropleth Mapper and Neighborhood Analysis Mapper (#134)
#   - BUG: extensive_variables and intensive_variables default to None not … (#133)
#   - ENH: adding template example (#131)
#   - remove errant files (#130)
#   - starting branch to explore prototypes (#129)
#   - update environment.yml (#128)
#   - update .coveragerc to ignore viz and util (#127)
#   - add harmonization tests (#126)
#   - refactor dynamics module (#125)
#   - improvements to harmonize function (#124)
#   - better handling of cluster internals (#123)
#   - allow returning cluster instances and return new community with methods (#121)
#   - BUG: extensive != intensive (#122)
#   - update requirements (#120)
#   - CLI/Docker (#119)
#   - [ENH] better tract handling (#118)
#   - check for block data inside data store (#117)
#   - add lodes constructor (#114)
#   - define harmonize in geosnap (#115)
#   - Docker (#112)
#   - start harmonization module (#111)
#   - update readme (#110)
#   - update notebooks (#108)
#   - fix imports in cenpy fetch (#106)
#   - remove notebook checkpoint dir (#105)
#   - remove old parquet file from setup script (#104)
#   - add dash dataset explorer (#102)
#   - update cenpy fetcher (#103)
#   - (ENH) add function for visualizing compositions of neighborhood sequence clusters  (#96)
#   - Docker (#100)
#   - rewrite Community class and internal data handling (#97)
#   - start lehd branch (#92)
#   - test plotting and catch quilt error (#79)
#   - Geosnap refactor (#75)
#   - Dependencies (#72)
#   - update travis yaml to use newer miniconda (#71)
#   - this PR moves all data mangement into quilt and fixes tests accordingly (#65)
#   - beginning a `util` module (#63)
#   - Update Sequence class (#56)
#   - Allow all the currency variables to be adjusted for inflation. (#62)
#   - add an option to specify constant year for inflation adjustment (#55)
#   - remove rounding in ltdb data reader (#57)
#   - update readme and some infrastucture changes (#52)

# %%
people = "\n".join(["  - "+person for person in unique_authors])

# %%
print(people)
# Out:
#   - Eli Knaap
#   - Wei Kang
#   - Serge Rey
#   - Su Han
#   - Renan Xavier Cortes
#   - Renanxcortes

# %%
message +="\n\nThe following individuals contributed to this release:\n\n{people}".format(people=people)

# %%
print(message)
# Out:
# We closed a total of 237 issues (enhancements and bug fixes) through 89 pull requests, since our last release on 2019-01-30.
#
# ## Issues Closed
#   - import broken with newer quilt versions (#201)
#   - Datasets (#205)
#   - User authentication (#41)
#   - migrate quilt data (#167)
#   - release prep (#170)
#   - issues with core data (#166)
#   - Google Colab pip install issue (#206)
#   - bump pyarrow (#204)
#   - bumpy pyarrow version (#203)
#   - bump version (#200)
#   - Merge pull request #199 from knaaptime/master (#199)
#   - Merge pull request #197 from knaaptime/master (#197)
#   - Merge pull request #196 from knaaptime/master (#196)
#   - Merge pull request #195 from knaaptime/master (#195)
#   - Merge pull request #194 from knaaptime/master (#194)
#   - remove unnecessary options from setup.py (#193)
#   - update docs; (#192)
#   - Merge pull request #191 from knaaptime/prep (#191)
#   - Merge pull request #190 from knaaptime/prep (#190)
#   - Vizsu (#187)
#   - Release on Conda? (#186)
#   - Update (#185)
#   - fix for lodes constructor (#183)
#   - Update README.md (#182)
#   - bug: drop duplicates from lehd (#181)
#   - add pooling option to cluster analytics (#84)
#   - add pooling option to clustering (#180)
#   - remove property decorators from datasets (#169)
#   - intersphinx and docstrings (#179)
#   - update (#178)
#   - update harmonize for new tobler api (#175)
#   - update (#177)
#   - upload images (#176)
#   - Vizsu (#174)
#   - big fix (#173)
#   - Vizsu (#172)
#   - point to reloacated  metadata in setup.py (#171)
#   - release prep (#165)
#   - fix years test in lodes constructor (#164)
#   - add user guide to apidoc navbar (#163)
#   - cosmetic updates to api docs (#162)
#   - fix lodes constructor and allow kwargs passed to weights  (#161)
#   - two fixes (#160)
#   - how to store the results of Community.cluster (#145)
#   - consider storing cluster metadata on a `Community` (#144)
#   - include tests for example notebooks (#159)
#   - nlcd is required for example 3 (#138)
#   - refactor (#158)
#   - generate DOI (#81)
#   - Update (#156)
#   - consider move to mkdocs (#140)
#   - update docs (#155)
#   - nojekyll (#153)
#   - move docs to gh-pages (#152)
#   - Cleaning files (#151)
#   - Update GEOSNAP2ACM and GEOSNAP2NAM (#150)
#   - Boundaryfix (#149)
#   - Update GEOSNAP2NAM.py (#147)
#   - updated comments in GEOSNAP2NAM.py (#146)
#   - update Readme and move LTDB_data_availability.xlsx (#143)
#   - fixed error in labelling (#142)
#   - GEOSNAP2NAM new version (#141)
#   - ENH: Makefile for joint tobler and geosnap dev environments (#139)
#   - Harmonize (#137)
#   - ENH: Dockerfile for join dev of geosnap and tobler. (#135)
#   - update outputs for GEOSNAP2ACM and GEOSNAP2NAM (#136)
#   - Jupyter Notebook for Adaptive Choropleth Mapper and Neighborhood Analysis Mapper (#134)
#   - BUG: extensive_variables and intensive_variables default to None not … (#133)
#   - Do we have example datasets with column defining neighborhood clusters for demonstration/testing purpose?  (#95)
#   - adding a table after the chropleth map in examples/02_creating_community_datasets.ipynb (#45)
#   - ENH: adding template example (#131)
#   - remove errant files (#130)
#   - consider pysal submodule (#93)
#   - starting branch to explore prototypes (#129)
#   - place api (#74)
#   - add tests (#66)
#   - update environment.yml (#128)
#   - add quilt3 in dependencies (#113)
#   - update .coveragerc to ignore viz and util (#127)
#   - add harmonization tests (#126)
#   - refactor dynamics module (#125)
#   - improvements to harmonize function (#124)
#   - geosnap depends on not most update scikit-learn api (#94)
#   - better handling of cluster internals (#123)
#   - return cluster instance  (#82)
#   - allow returning cluster instances and return new community with methods (#121)
#   - BUG: extensive != intensive (#122)
#   - add harmonization interface (#109)
#   - rework CI (#98)
#   - update requirements (#120)
#   - CLI/Docker (#119)
#   - [ENH] better tract handling (#118)
#   - (bug) inconsistency of localizing quilt3 data sets (#116)
#   - check for block data inside data store (#117)
#   - add lodes constructor (#114)
#   - define harmonize in geosnap (#115)
#   - Docker (#112)
#   - start harmonization module (#111)
#   - typo (#86)
#   - Creating a database fails due to bad file name (#23)
#   - update readme (#110)
#   - notebooks are not running successfully (#107)
#   - update notebooks (#108)
#   - Fix mislabeling in geosnap.data.dictionary (#90)
#   - parallelize gdf from wkb (#91)
#   - fix imports in cenpy fetch (#106)
#   - remove notebook checkpoint dir (#105)
#   - remove old parquet file from setup script (#104)
#   - add dash dataset explorer (#102)
#   - update census fetcher to use new cenpy api (#87)
#   - update cenpy fetcher (#103)
#   - dash chorobrewer explorer (#99)
#   - (ENH) add function for visualizing compositions of neighborhood sequence clusters  (#96)
#   - error related quilt upgrade to 3.0 (#85)
#   - Docker (#100)
#   - rewrite Community class and internal data handling (#97)
#   - cenpy interface (#73)
#   - consider GADM interface (#42)
#   - add a private function that loads all geoms into memory (#49)
#   - [WIP] Start of harmonization layer (#80)
#   - refactor Dataset to Community (#36)
#   - start lehd branch (#92)
#   - GEOSNAP2ACM (#89)
#   - Add GEOSNAP2ACM (#88)
#   - investigate moving from CGI to django (#50)
#   - parameter description of Kmeans (#51)
#   - catch error and update quilt package (#69)
#   - test plotting and catch quilt error (#79)
#   - importing geosnap (KeyError: 'states'?) (#78)
#   - Geosnap refactor (#75)
#   - bug: installation error on networkx  (#64)
#   - trim dependencies (#70)
#   - Dependencies (#72)
#   - update travis yaml to use newer miniconda (#71)
#   - move quilt data to spatialucr account (#28)
#   - move all shape data to quilt (#48)
#   - fix cluster tests (#58)
#   - expose util functions to users (#60)
#   - this PR moves all data mangement into quilt and fixes tests accordingly (#65)
#   - beginning a `util` module (#63)
#   - Update Sequence class (#56)
#   - LTDB reader: adjust for inflation? (#53)
#   - Allow all the currency variables to be adjusted for inflation. (#62)
#   - Reading LTBD data - inconsistent paths for full count and sample files? (#61)
#   - LTDB reader rounding to integers? (#54)
#   - add an option to specify constant year for inflation adjustment (#55)
#   - remove rounding in ltdb data reader (#57)
#   - update readme and some infrastucture changes (#52)
#
# ## Pull Requests
#   - Datasets (#205)
#   - bump pyarrow (#204)
#   - bump version (#200)
#   - Merge pull request #199 from knaaptime/master (#199)
#   - Merge pull request #197 from knaaptime/master (#197)
#   - Merge pull request #196 from knaaptime/master (#196)
#   - Merge pull request #195 from knaaptime/master (#195)
#   - Merge pull request #194 from knaaptime/master (#194)
#   - remove unnecessary options from setup.py (#193)
#   - update docs; (#192)
#   - Merge pull request #191 from knaaptime/prep (#191)
#   - Merge pull request #190 from knaaptime/prep (#190)
#   - Vizsu (#187)
#   - Update (#185)
#   - fix for lodes constructor (#183)
#   - Update README.md (#182)
#   - bug: drop duplicates from lehd (#181)
#   - add pooling option to clustering (#180)
#   - intersphinx and docstrings (#179)
#   - update (#178)
#   - update harmonize for new tobler api (#175)
#   - update (#177)
#   - Vizsu (#174)
#   - point to reloacated  metadata in setup.py (#171)
#   - release prep (#165)
#   - fix years test in lodes constructor (#164)
#   - add user guide to apidoc navbar (#163)
#   - cosmetic updates to api docs (#162)
#   - fix lodes constructor and allow kwargs passed to weights  (#161)
#   - two fixes (#160)
#   - refactor (#158)
#   - Update (#156)
#   - update docs (#155)
#   - nojekyll (#153)
#   - move docs to gh-pages (#152)
#   - Cleaning files (#151)
#   - Update GEOSNAP2ACM and GEOSNAP2NAM (#150)
#   - Boundaryfix (#149)
#   - Update GEOSNAP2NAM.py (#147)
#   - update Readme and move LTDB_data_availability.xlsx (#143)
#   - fixed error in labelling (#142)
#   - GEOSNAP2NAM new version (#141)
#   - ENH: Makefile for joint tobler and geosnap dev environments (#139)
#   - Harmonize (#137)
#   - ENH: Dockerfile for join dev of geosnap and tobler. (#135)
#   - update outputs for GEOSNAP2ACM and GEOSNAP2NAM (#136)
#   - Jupyter Notebook for Adaptive Choropleth Mapper and Neighborhood Analysis Mapper (#134)
#   - BUG: extensive_variables and intensive_variables default to None not … (#133)
#   - ENH: adding template example (#131)
#   - remove errant files (#130)
#   - starting branch to explore prototypes (#129)
#   - update environment.yml (#128)
#   - update .coveragerc to ignore viz and util (#127)
#   - add harmonization tests (#126)
#   - refactor dynamics module (#125)
#   - improvements to harmonize function (#124)
#   - better handling of cluster internals (#123)
#   - allow returning cluster instances and return new community with methods (#121)
#   - BUG: extensive != intensive (#122)
#   - update requirements (#120)
#   - CLI/Docker (#119)
#   - [ENH] better tract handling (#118)
#   - check for block data inside data store (#117)
#   - add lodes constructor (#114)
#   - define harmonize in geosnap (#115)
#   - Docker (#112)
#   - start harmonization module (#111)
#   - update readme (#110)
#   - update notebooks (#108)
#   - fix imports in cenpy fetch (#106)
#   - remove notebook checkpoint dir (#105)
#   - remove old parquet file from setup script (#104)
#   - add dash dataset explorer (#102)
#   - update cenpy fetcher (#103)
#   - (ENH) add function for visualizing compositions of neighborhood sequence clusters  (#96)
#   - Docker (#100)
#   - rewrite Community class and internal data handling (#97)
#   - start lehd branch (#92)
#   - test plotting and catch quilt error (#79)
#   - Geosnap refactor (#75)
#   - Dependencies (#72)
#   - update travis yaml to use newer miniconda (#71)
#   - this PR moves all data mangement into quilt and fixes tests accordingly (#65)
#   - beginning a `util` module (#63)
#   - Update Sequence class (#56)
#   - Allow all the currency variables to be adjusted for inflation. (#62)
#   - add an option to specify constant year for inflation adjustment (#55)
#   - remove rounding in ltdb data reader (#57)
#   - update readme and some infrastucture changes (#52)
#
# The following individuals contributed to this release:
#
#   - Eli Knaap
#   - Wei Kang
#   - Serge Rey
#   - Su Han
#   - Renan Xavier Cortes
#   - Renanxcortes

# %%
head = "# Changes\n\nVersion {version} ({release_date})\n\n".format(version=__version__, release_date=release_date)

# %%
print(head+message)
# Out:
# # Changes
#
# Version 0.1.6 (2020-03-11)
#
# We closed a total of 237 issues (enhancements and bug fixes) through 89 pull requests, since our last release on 2019-01-30.
#
# ## Issues Closed
#   - import broken with newer quilt versions (#201)
#   - Datasets (#205)
#   - User authentication (#41)
#   - migrate quilt data (#167)
#   - release prep (#170)
#   - issues with core data (#166)
#   - Google Colab pip install issue (#206)
#   - bump pyarrow (#204)
#   - bumpy pyarrow version (#203)
#   - bump version (#200)
#   - Merge pull request #199 from knaaptime/master (#199)
#   - Merge pull request #197 from knaaptime/master (#197)
#   - Merge pull request #196 from knaaptime/master (#196)
#   - Merge pull request #195 from knaaptime/master (#195)
#   - Merge pull request #194 from knaaptime/master (#194)
#   - remove unnecessary options from setup.py (#193)
#   - update docs; (#192)
#   - Merge pull request #191 from knaaptime/prep (#191)
#   - Merge pull request #190 from knaaptime/prep (#190)
#   - Vizsu (#187)
#   - Release on Conda? (#186)
#   - Update (#185)
#   - fix for lodes constructor (#183)
#   - Update README.md (#182)
#   - bug: drop duplicates from lehd (#181)
#   - add pooling option to cluster analytics (#84)
#   - add pooling option to clustering (#180)
#   - remove property decorators from datasets (#169)
#   - intersphinx and docstrings (#179)
#   - update (#178)
#   - update harmonize for new tobler api (#175)
#   - update (#177)
#   - upload images (#176)
#   - Vizsu (#174)
#   - big fix (#173)
#   - Vizsu (#172)
#   - point to reloacated  metadata in setup.py (#171)
#   - release prep (#165)
#   - fix years test in lodes constructor (#164)
#   - add user guide to apidoc navbar (#163)
#   - cosmetic updates to api docs (#162)
#   - fix lodes constructor and allow kwargs passed to weights  (#161)
#   - two fixes (#160)
#   - how to store the results of Community.cluster (#145)
#   - consider storing cluster metadata on a `Community` (#144)
#   - include tests for example notebooks (#159)
#   - nlcd is required for example 3 (#138)
#   - refactor (#158)
#   - generate DOI (#81)
#   - Update (#156)
#   - consider move to mkdocs (#140)
#   - update docs (#155)
#   - nojekyll (#153)
#   - move docs to gh-pages (#152)
#   - Cleaning files (#151)
#   - Update GEOSNAP2ACM and GEOSNAP2NAM (#150)
#   - Boundaryfix (#149)
#   - Update GEOSNAP2NAM.py (#147)
#   - updated comments in GEOSNAP2NAM.py (#146)
#   - update Readme and move LTDB_data_availability.xlsx (#143)
#   - fixed error in labelling (#142)
#   - GEOSNAP2NAM new version (#141)
#   - ENH: Makefile for joint tobler and geosnap dev environments (#139)
#   - Harmonize (#137)
#   - ENH: Dockerfile for join dev of geosnap and tobler. (#135)
#   - update outputs for GEOSNAP2ACM and GEOSNAP2NAM (#136)
#   - Jupyter Notebook for Adaptive Choropleth Mapper and Neighborhood Analysis Mapper (#134)
#   - BUG: extensive_variables and intensive_variables default to None not … (#133)
#   - Do we have example datasets with column defining neighborhood clusters for demonstration/testing purpose?  (#95)
#   - adding a table after the chropleth map in examples/02_creating_community_datasets.ipynb (#45)
#   - ENH: adding template example (#131)
#   - remove errant files (#130)
#   - consider pysal submodule (#93)
#   - starting branch to explore prototypes (#129)
#   - place api (#74)
#   - add tests (#66)
#   - update environment.yml (#128)
#   - add quilt3 in dependencies (#113)
#   - update .coveragerc to ignore viz and util (#127)
#   - add harmonization tests (#126)
#   - refactor dynamics module (#125)
#   - improvements to harmonize function (#124)
#   - geosnap depends on not most update scikit-learn api (#94)
#   - better handling of cluster internals (#123)
#   - return cluster instance  (#82)
#   - allow returning cluster instances and return new community with methods (#121)
#   - BUG: extensive != intensive (#122)
#   - add harmonization interface (#109)
#   - rework CI (#98)
#   - update requirements (#120)
#   - CLI/Docker (#119)
#   - [ENH] better tract handling (#118)
#   - (bug) inconsistency of localizing quilt3 data sets (#116)
#   - check for block data inside data store (#117)
#   - add lodes constructor (#114)
#   - define harmonize in geosnap (#115)
#   - Docker (#112)
#   - start harmonization module (#111)
#   - typo (#86)
#   - Creating a database fails due to bad file name (#23)
#   - update readme (#110)
#   - notebooks are not running successfully (#107)
#   - update notebooks (#108)
#   - Fix mislabeling in geosnap.data.dictionary (#90)
#   - parallelize gdf from wkb (#91)
#   - fix imports in cenpy fetch (#106)
#   - remove notebook checkpoint dir (#105)
#   - remove old parquet file from setup script (#104)
#   - add dash dataset explorer (#102)
#   - update census fetcher to use new cenpy api (#87)
#   - update cenpy fetcher (#103)
#   - dash chorobrewer explorer (#99)
#   - (ENH) add function for visualizing compositions of neighborhood sequence clusters  (#96)
#   - error related quilt upgrade to 3.0 (#85)
#   - Docker (#100)
#   - rewrite Community class and internal data handling (#97)
#   - cenpy interface (#73)
#   - consider GADM interface (#42)
#   - add a private function that loads all geoms into memory (#49)
#   - [WIP] Start of harmonization layer (#80)
#   - refactor Dataset to Community (#36)
#   - start lehd branch (#92)
#   - GEOSNAP2ACM (#89)
#   - Add GEOSNAP2ACM (#88)
#   - investigate moving from CGI to django (#50)
#   - parameter description of Kmeans (#51)
#   - catch error and update quilt package (#69)
#   - test plotting and catch quilt error (#79)
#   - importing geosnap (KeyError: 'states'?) (#78)
#   - Geosnap refactor (#75)
#   - bug: installation error on networkx  (#64)
#   - trim dependencies (#70)
#   - Dependencies (#72)
#   - update travis yaml to use newer miniconda (#71)
#   - move quilt data to spatialucr account (#28)
#   - move all shape data to quilt (#48)
#   - fix cluster tests (#58)
#   - expose util functions to users (#60)
#   - this PR moves all data mangement into quilt and fixes tests accordingly (#65)
#   - beginning a `util` module (#63)
#   - Update Sequence class (#56)
#   - LTDB reader: adjust for inflation? (#53)
#   - Allow all the currency variables to be adjusted for inflation. (#62)
#   - Reading LTBD data - inconsistent paths for full count and sample files? (#61)
#   - LTDB reader rounding to integers? (#54)
#   - add an option to specify constant year for inflation adjustment (#55)
#   - remove rounding in ltdb data reader (#57)
#   - update readme and some infrastucture changes (#52)
#
# ## Pull Requests
#   - Datasets (#205)
#   - bump pyarrow (#204)
#   - bump version (#200)
#   - Merge pull request #199 from knaaptime/master (#199)
#   - Merge pull request #197 from knaaptime/master (#197)
#   - Merge pull request #196 from knaaptime/master (#196)
#   - Merge pull request #195 from knaaptime/master (#195)
#   - Merge pull request #194 from knaaptime/master (#194)
#   - remove unnecessary options from setup.py (#193)
#   - update docs; (#192)
#   - Merge pull request #191 from knaaptime/prep (#191)
#   - Merge pull request #190 from knaaptime/prep (#190)
#   - Vizsu (#187)
#   - Update (#185)
#   - fix for lodes constructor (#183)
#   - Update README.md (#182)
#   - bug: drop duplicates from lehd (#181)
#   - add pooling option to clustering (#180)
#   - intersphinx and docstrings (#179)
#   - update (#178)
#   - update harmonize for new tobler api (#175)
#   - update (#177)
#   - Vizsu (#174)
#   - point to reloacated  metadata in setup.py (#171)
#   - release prep (#165)
#   - fix years test in lodes constructor (#164)
#   - add user guide to apidoc navbar (#163)
#   - cosmetic updates to api docs (#162)
#   - fix lodes constructor and allow kwargs passed to weights  (#161)
#   - two fixes (#160)
#   - refactor (#158)
#   - Update (#156)
#   - update docs (#155)
#   - nojekyll (#153)
#   - move docs to gh-pages (#152)
#   - Cleaning files (#151)
#   - Update GEOSNAP2ACM and GEOSNAP2NAM (#150)
#   - Boundaryfix (#149)
#   - Update GEOSNAP2NAM.py (#147)
#   - update Readme and move LTDB_data_availability.xlsx (#143)
#   - fixed error in labelling (#142)
#   - GEOSNAP2NAM new version (#141)
#   - ENH: Makefile for joint tobler and geosnap dev environments (#139)
#   - Harmonize (#137)
#   - ENH: Dockerfile for join dev of geosnap and tobler. (#135)
#   - update outputs for GEOSNAP2ACM and GEOSNAP2NAM (#136)
#   - Jupyter Notebook for Adaptive Choropleth Mapper and Neighborhood Analysis Mapper (#134)
#   - BUG: extensive_variables and intensive_variables default to None not … (#133)
#   - ENH: adding template example (#131)
#   - remove errant files (#130)
#   - starting branch to explore prototypes (#129)
#   - update environment.yml (#128)
#   - update .coveragerc to ignore viz and util (#127)
#   - add harmonization tests (#126)
#   - refactor dynamics module (#125)
#   - improvements to harmonize function (#124)
#   - better handling of cluster internals (#123)
#   - allow returning cluster instances and return new community with methods (#121)
#   - BUG: extensive != intensive (#122)
#   - update requirements (#120)
#   - CLI/Docker (#119)
#   - [ENH] better tract handling (#118)
#   - check for block data inside data store (#117)
#   - add lodes constructor (#114)
#   - define harmonize in geosnap (#115)
#   - Docker (#112)
#   - start harmonization module (#111)
#   - update readme (#110)
#   - update notebooks (#108)
#   - fix imports in cenpy fetch (#106)
#   - remove notebook checkpoint dir (#105)
#   - remove old parquet file from setup script (#104)
#   - add dash dataset explorer (#102)
#   - update cenpy fetcher (#103)
#   - (ENH) add function for visualizing compositions of neighborhood sequence clusters  (#96)
#   - Docker (#100)
#   - rewrite Community class and internal data handling (#97)
#   - start lehd branch (#92)
#   - test plotting and catch quilt error (#79)
#   - Geosnap refactor (#75)
#   - Dependencies (#72)
#   - update travis yaml to use newer miniconda (#71)
#   - this PR moves all data mangement into quilt and fixes tests accordingly (#65)
#   - beginning a `util` module (#63)
#   - Update Sequence class (#56)
#   - Allow all the currency variables to be adjusted for inflation. (#62)
#   - add an option to specify constant year for inflation adjustment (#55)
#   - remove rounding in ltdb data reader (#57)
#   - update readme and some infrastucture changes (#52)
#
# The following individuals contributed to this release:
#
#   - Eli Knaap
#   - Wei Kang
#   - Serge Rey
#   - Su Han
#   - Renan Xavier Cortes
#   - Renanxcortes

# %%
outfile = 'changelog_{version}.md'.format(version=__version__)
with open(outfile, 'w') as of:
    of.write(head+message)
