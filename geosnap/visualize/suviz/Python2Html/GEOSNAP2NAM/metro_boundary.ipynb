# %%
from geosnap.data import data_store
metros = data_store.msas()

# %%
metros
# Out:
#      geoid                               name        type  \
# 0    10100                       Aberdeen, SD  Micro Area
# 1    10140                       Aberdeen, WA  Micro Area
# 2    10180                        Abilene, TX  Metro Area
# 3    10220                            Ada, OK  Micro Area
# 4    10260                       Adjuntas, PR  Micro Area
# ..     ...                                ...         ...
# 940  49660  Youngstown-Warren-Boardman, OH-PA  Metro Area
# 941  49700                      Yuba City, CA  Metro Area
# 942  49740                           Yuma, AZ  Metro Area
# 943  49780                     Zanesville, OH  Micro Area
# 944  49820                         Zapata, TX  Micro Area
#
#                                               geometry
# 0    POLYGON ((-98.722481 45.243764, -98.72542 45.2...
# 1    POLYGON ((-124.305419 47.244644, -124.306367 4...
# 2    POLYGON ((-100.146543 32.522793, -100.146425 3...
# ...
